# %% [markdown]
# <a href="https://colab.research.google.com/github/ArmstrongVo/ArmstrongVo.github.io/blob/main/AI_W5_Advertising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import figure
#from skfuzzy.membership.generatemf import gaussmf
import matplotlib.pyplot as plt
#from skfuzzy import control as ctrl 
import numpy as np
#import skfuzzy as fuzz
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axis3d
import pandas as pd
url = 'Advertising.csv'
data = pd.read_csv(url)
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr() # mối tương quan giữa các biến, trị số lớn nhất là ảnh hưởng nhiều nhất, TLT HAY TLN  phụ thuộc vào dấu + or -
print(correlation)
import seaborn as sns   # thư viện hiển thị dữ liệu
#sns.pairplot(data)
sns.heatmap(correlation,annot=True)
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000
# <AxesSubplot:>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X=pd.DataFrame([data['TV'],data['TV']**2]).T
model.fit(X,y=data['sales'])
print('intercept của mô hình',model.intercept_)
print('coef của mô hình',model.coef_)
print('độ chính xác của mô hình',model.score(X,y=data['sales']))
data.plot(kind = 'scatter', x = 'TV', y='sales',figsize = (9,9), color = 'black',xlim=(0,150))
range = np.arange(1.5,100.5,0.1)
predictor = pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# intercept của mô hình 6.1141201283331075
# coef của mô hình [ 6.72659270e-02 -6.84693373e-05]
# độ chính xác của mô hình 0.6190371168872755
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X=pd.DataFrame([data['TV'],data['TV']**2,data['TV']**3,data['TV']**4,data['TV']**5]).T
model.fit(X,y=data['sales'])
print('intercept của mô hình',model.intercept_)
print('coef của mô hình',model.coef_)
print('độ chính xác của mô hình',model.score(X,y=data['sales']))
data.plot(kind = 'scatter', x = 'TV', y='sales',figsize = (9,9), color = 'black',xlim=(0,100))
range = np.arange(1.5,95,0.1)
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# intercept của mô hình 3.434534787401425
# coef của mô hình [ 2.77902843e-01 -4.26334402e-03  3.38693899e-05 -1.20207585e-07
#   1.55728366e-10]
# độ chính xác của mô hình 0.6289510709142143
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
