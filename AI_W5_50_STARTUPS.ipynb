# %% [markdown]
# <a href="https://colab.research.google.com/github/ArmstrongVo/ArmstrongVo.github.io/blob/main/AI_W5_50_STARTUPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import figure
#from skfuzzy.membership.generatemf import gaussmf
import matplotlib.pyplot as plt
#from skfuzzy import control as ctrl 
import numpy as np
#import skfuzzy as fuzz
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axis3d
import pandas as pd
url = '50_Startups.csv'
data = pd.read_csv(url)
data.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr() # mối tương quan giữa các biến, trị số lớn nhất là ảnh hưởng nhiều nhất, TLT HAY TLN  phụ thuộc vào dấu + or -
print(correlation)
import seaborn as sns   # thư viện hiển thị dữ liệu
#sns.pairplot(data)
sns.heatmap(correlation,annot=True)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000
# <AxesSubplot:>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('intercept của mô hình',model.intercept_)
print('coef của mô hình',model.coef_)
print('độ chính xác của mô hình',model.score(X,y=data['Profit']))
data.plot(kind = 'scatter', x = 'R&D Spend', y='Profit',figsize = (9,9), color = 'black',xlim=(0,150000))
range = np.arange(1.5,100000.5,1)
predictor = pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# intercept của mô hình 48128.14916956878
# coef của mô hình [ 8.90147291e-01 -2.31821806e-07]
# độ chính xác của mô hình 0.946703652909133
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4,data['R&D Spend']**5]).T
model.fit(X,y=data['Profit'])
print('intercept của mô hình',model.intercept_)
print('coef của mô hình',model.coef_)
print('độ chính xác của mô hình',model.score(X,y=data['Profit']))
data.plot(kind = 'scatter', x = 'R&D Spend', y='Profit',figsize = (9,9), color = 'black',xlim=(0,150000))
range = np.arange(1.5,100000.5,10)
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# intercept của mô hình 62755.68248568247
# coef của mô hình [ 1.32995066e-19  1.41519102e-14  3.43374411e-10 -3.89058927e-15
#   1.21062645e-20]
# độ chính xác của mô hình 0.9088995842501878
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3,data['R&D Spend']**4]).T
model.fit(X,y=data['Profit'])
print('intercept của mô hình',model.intercept_)
print('coef của mô hình',model.coef_)
print('độ chính xác của mô hình',model.score(X,y=data['Profit']))
data.plot(kind = 'scatter', x = 'R&D Spend', y='Profit',figsize = (9,9), color = 'black',xlim=(0,150000))
range = np.arange(1.5,100000.5,10)
predictor = pd.DataFrame([range,range**2,range**3,range**4]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# intercept của mô hình 54454.40996740002
# coef của mô hình [ 6.45872939e-10  2.52519103e-05 -2.52720474e-10  8.00998401e-16]
# độ chính xác của mô hình 0.9338075472558462
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
X=pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2,data['R&D Spend']**3]).T
model.fit(X,y=data['Profit'])
print('intercept của mô hình',model.intercept_)
print('coef của mô hình',model.coef_)
print('độ chính xác của mô hình',model.score(X,y=data['Profit']))
data.plot(kind = 'scatter', x = 'R&D Spend', y='Profit',figsize = (9,9), color = 'black',xlim=(0,150000))
range = np.arange(1.5,100000.5,10)
predictor = pd.DataFrame([range,range**2,range**3]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='blue')
# Out:
# intercept của mô hình 43108.76756818297
# coef của mô hình [ 1.40072682e+00 -8.82403324e-06  3.64774030e-11]
# độ chính xác của mô hình 0.9540709421464032
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
