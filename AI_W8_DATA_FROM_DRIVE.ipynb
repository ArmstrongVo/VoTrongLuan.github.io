# %% [markdown]
# <a href="https://colab.research.google.com/github/ArmstrongVo/VoTrongLuan.github.io/blob/main/AI_W8_DATA_FROM_DRIVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread 
folder = '/content/drive/MyDrive/aa/AI/'
for i in range (25):
  plt.subplot(5,5,i+1)
  filename = folder +'luan'+str(i)+'.jpg'
  img=imread(filename)
  plt.imshow(img)
plt.show()
